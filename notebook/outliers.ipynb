# %%
import pandas as pd

# %%
data = pd.read_csv('airbnb_data.csv')
df = pd.DataFrame(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5548 entries, 0 to 5547
# Data columns (total 43 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             5548 non-null   int64
#  1   level_0                5548 non-null   int64
#  2   _id                    5548 non-null   int64
#  3   listing_url            5548 non-null   object
#  4   name                   5548 non-null   object
#  5   summary                5548 non-null   object
#  6   space                  5548 non-null   object
#  7   description            5548 non-null   object
#  8   neighborhood_overview  5548 non-null   object
#  9   notes                  5548 non-null   object
#  10  transit                5548 non-null   object
#  11  access                 5548 non-null   object
#  12  interaction            5548 non-null   object
#  13  house_rules            5548 non-null   object
# ...

# %%
df.drop(columns=['Unnamed: 0.3','Unnamed: 0.2','Unnamed: 0.1'],axis =1,inplace = True)

# %%
df.rename(columns = {'Unnamed: 0':'index'},inplace = True)

# %%
df.to_csv('airbnb_data.csv')

# %%
data_add = pd.read_csv('address.csv')
df_add = pd.DataFrame(data_add)

# %%
merged_df = pd.merge(df,df_add,on = '_id',how = 'inner')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5548 entries, 0 to 5553
# Data columns (total 43 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             5548 non-null   int64
#  1   index                  5548 non-null   int64
#  2   _id                    5548 non-null   int64
#  3   listing_url            5548 non-null   object
#  4   name                   5548 non-null   object
#  5   summary                5548 non-null   object
#  6   space                  5548 non-null   object
#  7   description            5548 non-null   object
#  8   neighborhood_overview  5548 non-null   object
#  9   notes                  5548 non-null   object
#  10  transit                5548 non-null   object
#  11  access                 5548 non-null   object
#  12  interaction            5548 non-null   object
#  13  house_rules            5548 non-null   object
# ...

# %%
numeric_columns = ['minimum_nights','maximum_nights','accommodates','bedrooms','beds','bathrooms','price','security_deposit','cleaning_fee','extra_people','guests_included']

# %%
import plotly.express as px
corr_df = merged_df[numeric_columns].corr().round(1)
fig = px.imshow(
    corr_df,
    text_auto = True
)
fig.show()

# %%
df['maximum_nights'].value_counts()
# Out:
# maximum_nights
# 1125    3159
# 30       361
# 365      192
# 90       168
# 60       132
#         ...
# 720        1
# 140        1
# 103        1
# 69         1
# 224        1
# Name: count, Length: 140, dtype: int64

# %%
df['minimum_nights'].max()
# Out:
# np.float64(8.5)

# %%
df['maximum_nights'].max()
# Out:
# np.float64(2766.0)

# %%
px.box(df,
       x = 'price')

# %%
market = {}
country = list(merged_df['country'].unique())
# for i in country:
#     market_list = list(merged_df[merged_df['country'] == i]['market'].unique())
#     market[i] = market_list
# market

# %%
import numpy as np
for i in country:
    print(i)
    data = merged_df[merged_df['country']==i]['maximum_nights']
    q1 = np.quantile(data.values, 0.25)
    q2 = np.quantile(data.values, 0.50)
    q3 = np.quantile(data.values, 0.75)
    minimum = q1-(1.5 * (q3-q1))
    maximum = q3+(1.5 * (q3-q1))
    for j in data.keys():
        if df.loc[j,'maximum_nights'] > maximum:
            df.loc[j,'maximum_nights'] = maximum
        if df.loc[j,'maximum_nights'] < minimum:
            df.loc[j,'maximum_nights'] = minimum
# Out:
# United States
# China
# C:\Users\GIRI\AppData\Local\Temp\ipykernel_7544\319515554.py:12: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '2268.75' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# Australia
# Portugal
# Brazil
# Canada
# Turkey
# Spain

# %%
data.values
# Out:
# array([  1,   2, 200,   2,   2,   2,   2,   2,   1,  32,  32,   1,   4,
#          3,  32,  31,   1,   2,   1,   1,   1,   1,   1,  31,   1,  32,
#          1,   1,   3,   2,   2,   4,   3,   3,   4,   1,  35,   3,  32,
#          1,   3,   1,   1,   5,   3,   1,  32,   4,   3,   3,   6,   3,
#         32,   1,   1,   1,   2,   2,   3,   3,  32,   3,   2,   3,   2,
#          2,   3,   2,   2,  32,   3,   2,  32,   1,  31,   3,   3,   1,
#          1,   2,   2,   3,   3,   2,   2,   3,  32,   1,   1,  32,   3,
#          1,   4,   1,   1,   2,   2,   3,   2,   1,  32,   7,   1,   3,
#         32,   2,   2,   4,  31,   3,   2,   3,  32,   2,   3,  32,   5,
#          5,   1,   1,  31,   1,   2,   2,   3,   2,   3,   2,   1,   3,
#          1,   3,   1,  32,  32,   3,   1,   1,   2,   5,   2,   1,   2,
#         32,   2,  32,   2,   5,   1,   4,   2,   2,  31,   1,   1,   3,
#          1,   1,   2,   1,   2,   1,   4,   4,  32,   1,   2,   4,   3,
# ...

# %%
df.drop(axis = 0,index = g.keys(),inplace = True)

# %%
df.reset_index(inplace = True)

# %%
df['beds'].isnull().sum()
# Out:
# np.int64(0)

# %%
country = list(merged_df['country'].unique())
for i in country:
    property = merged_df[(merged_df['country'] == i)]['property_type'].unique()
    for j in property:
        bedroom = merged_df[(merged_df['country'] == i)&(merged_df['property_type']==j)]['bedrooms'].unique()
        for k in bedroom:
            bed = merged_df[(merged_df['country'] == i)&(merged_df['property_type']==j)&(merged_df['bedrooms']==k)]['beds'].unique()
            for l in bed:
                price = merged_df[(merged_df['country'] == i)&(merged_df['property_type']==j)&(merged_df['bedrooms']==k)&(merged_df['beds']==l)]['price']
                if len(price.values) >0:
                    q1 = np.quantile(price.values, 0.25)
                    q2 = np.quantile(price.values, 0.50)
                    q3 = np.quantile(price.values, 0.75)
                    minimum = q1-(1.5 * (q3-q1))
                    maximum = q3+(1.5 * (q3-q1))
                    print(price)
                    for j in price.keys():
                        if df.loc[j,'price'] > maximum:
                            df.loc[j,'price'] = maximum
                        if df.loc[j,'price'] < minimum:
                            df.loc[j,'price'] = minimum
# Out:
# 0       135.0
# 5       145.0
# 6        45.0
# 7        40.0
# 22      150.0
#         ...
# 5499     32.0
# 5502    450.0
# 5524    133.0
# 5528    108.0
# 5540    160.0
# Name: price, Length: 328, dtype: float64
# 27       115.0
# 178      239.0
# 193     1000.0
# 241      125.0
# 401      150.0
#          ...
# 5210     400.0
# 5256     135.0
# 5346     140.0
# 5360     155.0
# 5364     195.0
# Name: price, Length: 66, dtype: float64
# 59    185.0
# Name: price, dtype: float64
# 63      795.0
# 4770    525.0
# Name: price, dtype: float64
# 64      120.0
# 955     115.0
# 1237     74.0
# 1310    120.0
# 1355     58.0
# 1356     59.0
# 1983     65.0
# 2767     85.0
# 4017     89.0
# Name: price, dtype: float64
# 72      139.0
# 490      65.0
# 666      95.0
# 933     142.0
# 942     130.0
# 1169    290.0
# 1550     68.0
# 1697    155.0
# 1723    150.0
# 1932     80.0
# 2013     65.0
# 3860     67.0
# 4350     89.0
# 4559     79.0
# 5479    119.0
# Name: price, dtype: float64
# ...

# %%
q1 = np.quantile(price.values, 0.25)
q1
# Out:
# np.float64(135.0)

# %%
df.to_csv('airbnb_data.csv')
