# %%
import pandas as pd
import numpy as np

# %%
# data = pd.read_json('sample_airbnb.json')
# df = pd.DataFrame(data)
data = pd.read_csv('airbnb_data.csv')
df = pd.DataFrame(data)
df_copy = df.copy()

# %%
df.head(1)
# Out:
#        _id                           listing_url  \
# 0  1003530  https://www.airbnb.com/rooms/1003530
#
#                                   name summary  \
# 0  New York City - Upper West Side Apt
#
#                                                space  \
# 0  Murphy bed, optional second bedroom available....
#
#                                          description  \
# 0  Murphy bed, optional second bedroom available....
#
#                                neighborhood_overview  \
# 0  Great neighborhood - many terrific restaurants...
#
#                                                notes  \
# 0  My cat, Samantha, are in and out during the su...
#
#                                              transit          access  ...  \
# 0  Conveniently located near 1, 2, 3, B & C subwa...  New York City!  ...
#
#   guests_included                                             images  \
# 0               1  {'thumbnail_url': '', 'medium_url': '', 'pictu...
#
# ...

# %%
df.size
# Out:
# 233310

# %%
df.shape
# Out:
# (5555, 41)

# %%
colm = df.columns
len(colm)
# Out:
# 41

# %%
null_colm = ['first_review','last_review','bedrooms','beds','bathrooms','security_deposit','cleaning_fee','weekly_price','monthly_price','reviews_per_month']

# %%
show_colm = colm[35]
df[show_colm]
# Out:
# 0       {'street': 'New York, NY, United States', 'sub...
# 1       {'street': 'Fatih , İstanbul, Turkey', 'suburb...
# 2       {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 3       {'street': 'Hong Kong , 九龍, Hong Kong', 'subur...
# 4       {'street': 'Surry Hills, NSW, Australia', 'sub...
#                               ...
# 5550    {'street': 'Kadıköy, İstanbul, Turkey', 'subur...
# 5551    {'street': 'Lahaina, HI, United States', 'subu...
# 5552    {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 5553    {'street': 'Bondi Beach, NSW, Australia', 'sub...
# 5554    {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
# Name: address, Length: 5555, dtype: object

# %%
d.iloc[1]
# Out:
# [{'_id': '149469150',
#   'date': '2017-05-04 04:00:00',
#   'listing_id': '10133554',
#   'reviewer_id': '12428834',
#   'reviewer_name': 'Tara',
#   'comments': 'AMAZING time. Great price, clean room. The staff were the best!!'},
#  {'_id': '150131865',
#   'date': '2017-05-07 04:00:00',
#   'listing_id': '10133554',
#   'reviewer_id': '12428834',
#   'reviewer_name': 'Tara',
#   'comments': 'Great location, amazing food and vibe downstairs. We ate downstairs every night & enjoyed their wonderful company. Super friendly staff and help you any chance they can. \nThe room is on top of the bar so at night it is a little noisy but we were okay with it. \nReally nice part of town. 2 minute walk to Hagia Sophia, the palace, museums, and other food options. \nThe room was just like the photos! Clean and modern. '},
#  {'_id': '151850175',
#   'date': '2017-05-14 04:00:00',
#   'listing_id': '10133554',
#   'reviewer_id': '39119353',
#   'reviewer_name': 'Matt',
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 41 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             5555 non-null   int64
#  1   _id                    5555 non-null   int64
#  2   listing_url            5555 non-null   object
#  3   name                   5547 non-null   object
#  4   summary                5297 non-null   object
#  5   space                  3929 non-null   object
#  6   description            5460 non-null   object
#  7   neighborhood_overview  3314 non-null   object
#  8   notes                  2474 non-null   object
#  9   transit                3323 non-null   object
#  10  access                 3102 non-null   object
#  11  interaction            3077 non-null   object
#  12  house_rules            3270 non-null   object
#  13  property_type          5555 non-null   object
# ...

# %%
df_copy = df.copy()

# %%
df_copy = df_copy.drop(columns = ['reviews_per_month'], axis = 1)

# %%
df_copy.to_csv('airbnb_data.csv')

# %%
df_copy[['last_scraped','first_review', 'last_review','number_of_reviews','review_scores','reviews']]
# Out:
#              last_scraped         first_review          last_review  \
# 0     2019-03-07 05:00:00  2013-04-29 04:00:00  2018-08-12 04:00:00
# 1     2019-02-18 05:00:00  2017-05-04 04:00:00  2018-05-07 04:00:00
# 2     2019-03-11 04:00:00  2015-12-19 05:00:00  2018-03-27 04:00:00
# 3     2019-03-11 04:00:00  2015-12-22 05:00:00  2019-03-01 05:00:00
# 4     2019-03-07 05:00:00  2016-12-29 05:00:00  2018-03-18 04:00:00
# ...                   ...                  ...                  ...
# 5550  2019-02-18 05:00:00                  NaN                  NaN
# 5551  2019-03-06 05:00:00  2016-04-06 04:00:00  2018-08-20 04:00:00
# 5552  2019-03-11 04:00:00  2016-10-02 04:00:00  2017-01-01 05:00:00
# 5553  2019-03-07 05:00:00                  NaN                  NaN
# 5554  2019-02-11 05:00:00                  NaN                  NaN
#
#       number_of_reviews                                      review_scores  \
# ...

# %%
added = 0
for i in range(0,5555,1):
    print(df_copy['last_scraped'][i], df_copy['calendar_last_scraped'][i])
    if df_copy['last_scraped'][i] == df_copy['calendar_last_scraped'][i]:
        added = added + 1
print(added)
# Out:
# 2019-03-07 05:00:00 2019-03-07 05:00:00
# 2019-02-18 05:00:00 2019-02-18 05:00:00
# 2019-03-11 04:00:00 2019-03-11 04:00:00
# 2019-03-11 04:00:00 2019-03-11 04:00:00
# 2019-03-07 05:00:00 2019-03-07 05:00:00
# 2019-02-16 05:00:00 2019-02-16 05:00:00
# 2019-03-06 05:00:00 2019-03-06 05:00:00
# 2019-03-07 05:00:00 2019-03-07 05:00:00
# 2019-03-06 05:00:00 2019-03-06 05:00:00
# 2019-02-11 05:00:00 2019-02-11 05:00:00
# 2019-03-11 04:00:00 2019-03-11 04:00:00
# 2019-02-11 05:00:00 2019-02-11 05:00:00
# 2019-02-11 05:00:00 2019-02-11 05:00:00
# 2019-03-11 04:00:00 2019-03-11 04:00:00
# 2019-02-18 05:00:00 2019-02-18 05:00:00
# 2019-02-16 05:00:00 2019-02-16 05:00:00
# 2019-02-16 05:00:00 2019-02-16 05:00:00
# 2019-03-06 05:00:00 2019-03-06 05:00:00
# 2019-02-11 05:00:00 2019-02-11 05:00:00
# 2019-03-11 04:00:00 2019-03-11 04:00:00
# 2019-02-11 05:00:00 2019-02-11 05:00:00
# 2019-03-07 05:00:00 2019-03-07 05:00:00
# 2019-03-08 05:00:00 2019-03-08 05:00:00
# ...

# %%
df_copy = df_copy.drop(columns = ['calendar_last_scraped'], axis = 1)

# %%
df_copy['bedrooms'][df_copy['bedrooms'].isnull()]
# Out:
# 240    NaN
# 3278   NaN
# 4170   NaN
# Name: bedrooms, dtype: float64

# %%
df_copy['beds'][df_copy['beds'].isnull()]
# Out:
# 130    NaN
# 466    NaN
# 2067   NaN
# 3571   NaN
# 3592   NaN
# 3622   NaN
# 4121   NaN
# 4255   NaN
# 4628   NaN
# 5077   NaN
# 5273   NaN
# Name: beds, dtype: float64

# %%
zero = []
for i in range(len(bedroom_y_n.keys())):
    if bedroom_y_n.keys()[i] in bed_y_n.keys():
        zero.append(int(bedroom_y_n.keys()[i]))
print(zero)
# Out:
# [1275, 1399]

# %%
for i in zero:
    df_copy['beds'].iloc[i] = 0

# %%
df_copy['bedrooms'] = df_copy['bedrooms'].fillna(df_copy['bedrooms'].mode().values[0])

# %%
df_copy['beds'].value_counts()
# Out:
# beds
# 1.0     2700
# 2.0     1381
# 3.0      657
# 4.0      385
# 5.0      166
# 6.0      109
# 7.0       43
# 0.0       31
# 8.0       28
# 10.0      16
# 9.0       11
# 12.0       5
# 11.0       3
# 15.0       2
# 14.0       2
# 16.0       2
# 25.0       1
# 13.0       1
# 18.0       1
# Name: count, dtype: int64

# %%
df_copy['beds'] = df_copy['beds'].fillna(df_copy['beds'].mode().values[0])

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             5555 non-null   int64
#  1   _id                    5555 non-null   int64
#  2   listing_url            5555 non-null   object
#  3   name                   5555 non-null   object
#  4   summary                5555 non-null   object
#  5   space                  5555 non-null   object
#  6   description            5555 non-null   object
#  7   neighborhood_overview  5555 non-null   object
#  8   notes                  5555 non-null   object
#  9   transit                5555 non-null   object
#  10  access                 5555 non-null   object
#  11  interaction            5555 non-null   object
#  12  house_rules            5555 non-null   object
#  13  property_type          5555 non-null   object
# ...

# %%
df_copy['property_type'].value_counts()
# Out:
# property_type
# Apartment                 3626
# House                      606
# Condominium                399
# Serviced apartment         185
# Loft                       142
# Townhouse                  108
# Guest suite                 81
# Bed and breakfast           69
# Boutique hotel              53
# Guesthouse                  50
# Hostel                      34
# Villa                       32
# Hotel                       26
# Aparthotel                  23
# Cottage                     20
# Other                       18
# Cabin                       15
# Bungalow                    14
# Resort                      11
# Farm stay                    9
# Casa particular (Cuba)       9
# Tiny house                   7
# Boat                         2
# Nature lodge                 2
# Chalet                       2
# Camper/RV                    2
# Pension (South Korea)        1
# Houseboat                    1
# Castle                       1
# ...

# %%
name_nan = list(df_copy['name'][df_copy['name'].isnull()].keys())
name_nan
# Out:
# [63, 169, 212, 287, 3278, 4384, 5496, 5540]

# %%
for i in name_nan:
    df_copy.loc[i, 'name'] = df_copy['property_type'][i]

# %%
df_copy['summary'] = df_copy['summary'].fillna('No summary')

# %%
df_copy['space'] = df_copy['space'].fillna('Contact Host')

# %%
df_copy['description'] = df_copy['description'].fillna('No description')

# %%
df_copy['neighborhood_overview'] = df_copy['neighborhood_overview'].fillna('No overview')

# %%
df_copy['notes'] = df_copy['notes'].fillna('Contact Host')

# %%
df_copy['transit'] = df_copy['transit'].fillna('Contact Host')

# %%
df_copy['house_rules'] = df_copy['house_rules'].fillna('Contact Host')

# %%
inter_nan = list(df_copy['interaction'][df_copy['interaction'].isnull()].keys())

# %%
import ast
for i in inter_nan:
    df_copy.loc[i, 'interaction'] = ast.literal_eval(df_copy['host'][i])['host_url']

# %%
import ast
a = df_copy['host'].iloc[0]
a = ast.literal_eval(a)
type(a)
# Out:
# dict

# %%
df_copy['bathrooms'] = df_copy['bathrooms'].fillna(df_copy['bathrooms'].mode().values[0])

# %%
df_copy['property_type'].value_counts()
# Out:
# property_type
# Apartment                 3626
# House                      606
# Condominium                399
# Serviced apartment         185
# Loft                       142
# Townhouse                  108
# Guest suite                 81
# Bed and breakfast           69
# Boutique hotel              53
# Guesthouse                  50
# Hostel                      34
# Villa                       32
# Hotel                       26
# Aparthotel                  23
# Cottage                     20
# Other                       18
# Cabin                       15
# Bungalow                    14
# Resort                      11
# Farm stay                    9
# Casa particular (Cuba)       9
# Tiny house                   7
# Boat                         2
# Nature lodge                 2
# Chalet                       2
# Camper/RV                    2
# Pension (South Korea)        1
# Houseboat                    1
# Castle                       1
# ...

# %%
print(df_copy[['property_type','price','security_deposit','cleaning_fee']][df_copy['property_type'] == 'Apartment'])
# Out:
#      property_type  price  security_deposit  cleaning_fee
# 0        Apartment    135               0.0         135.0
# 2        Apartment    699               NaN           NaN
# 4        Apartment    181             300.0          50.0
# 6        Apartment    145               NaN          60.0
# 7        Apartment     45               NaN           NaN
# ...            ...    ...               ...           ...
# 5548     Apartment    101               0.0          50.0
# 5549     Apartment     41               0.0          35.0
# 5552     Apartment    400            3000.0           NaN
# 5553     Apartment     60               NaN          50.0
# 5554     Apartment    750               NaN           NaN
#
# [3626 rows x 4 columns]

# %%
df_clean_fee= df_copy.groupby(['property_type'])['cleaning_fee'].mean()

# %%
clean_indx = list(df_copy[df_copy['cleaning_fee'].isnull()].index)

# %%
df_copy.shape
# Out:
# (5554, 40)

# %%
for i in clean_indx:
    df_copy.loc[i, 'cleaning_fee'] = df_clean_fee[df_copy.loc[i, 'property_type']]

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5554 entries, 0 to 5553
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _id                    5554 non-null   int64
#  1   listing_url            5554 non-null   object
#  2   name                   5554 non-null   object
#  3   summary                5554 non-null   object
#  4   space                  5554 non-null   object
#  5   description            5554 non-null   object
#  6   neighborhood_overview  5554 non-null   object
#  7   notes                  5554 non-null   object
#  8   transit                5554 non-null   object
#  9   access                 5554 non-null   object
#  10  interaction            5554 non-null   object
#  11  house_rules            5554 non-null   object
#  12  property_type          5554 non-null   object
#  13  room_type              5554 non-null   object
# ...

# %%
df_copy['security_deposit'] = df_copy['security_deposit'].fillna(0)

# %%
df_copy['cleaning_fee'] = df_copy['cleaning_fee'].fillna(0)

# %%
df_copy.to_csv('airbnb_data.csv')

# %%
df_copy=df_copy.drop(columns=['weekly_price', 'monthly_price'], axis = 1)

# %%
df_copy=df_copy.drop(columns=['first_review', 'last_review'], axis = 1)
